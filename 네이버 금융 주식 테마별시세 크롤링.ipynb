# %%
import sys # 시스템
import os  # 시스템

import pandas as pd  # 판다스 : 데이터분석 라이브러리
import numpy as np   # 넘파이 : 숫자, 행렬 데이터 라이브러리
import requests

from selenium import webdriver   # 웹 브라우저 자동화
import time    # 서버와 통신할 때 중간중간 시간 지연. 보통은 1초

# %%
#크롬 웹브라우저 실행
driver = webdriver.Chrome("./chromedriver")
url = "https://finance.naver.com/sise/theme.nhn?&page=1"
driver.get(url)
time.sleep(2)

# %%
# 해당 html소스에 있는 테이블들을 list안에 있는 dataframe형태로 table 변수에 할당
html = requests.get('https://finance.naver.com/sise/theme.nhn?&page=1') 
table = pd.read_html(html.text)

# %%
table[0]
# Out:
#            테마명    전일대비 최근3일등락률(평균) 전일대비 등락현황                 주도주
#            테마명    전일대비 최근3일등락률(평균)        상승   보합    하락      주도주    주도주.1
# 0      두나무 관련주  +5.28%      -0.38%       6.0  0.0   5.0  에이티넘인..  우리기술투..
# 1          창투사  +4.55%      -0.66%      10.0  0.0   6.0  에이티넘인..  우리기술투..
# 2           사료  +3.82%      -0.08%      13.0  1.0   4.0       한탑     대한제당
# 3   코로나19(모더나)  +2.21%      +1.35%       7.0  0.0   2.0  에이비프로..      엔투텍
# 4    리츠(REITs)  +2.11%      +0.36%       6.0  1.0   6.0     에이리츠  ESR켄달..
# ..         ...     ...         ...       ...  ...   ...      ...      ...
# 58        블록체인  -0.56%      +0.22%       4.0  6.0  19.0     대성창투       KT
# 59         면세점  -0.58%      +2.39%       4.0  0.0   5.0  제이에스티..     토니모리
# 60     철강 주요종목  -0.58%      +3.78%       4.0  0.0   6.0    포스코강판    세아베스틸
# 61         NaN     NaN         NaN       NaN  NaN   NaN      NaN      NaN
# 62         NaN     NaN         NaN       NaN  NaN   NaN      NaN      NaN
#
# [63 rows x 8 columns]

# %%
stock = table[0].dropna().reset_index(drop = True)
stock
# Out:
#                   테마명    전일대비 최근3일등락률(평균) 전일대비 등락현황                  주도주  \
#                   테마명    전일대비 최근3일등락률(평균)        상승    보합    하락      주도주
# 0             두나무 관련주  +5.28%      -0.38%       6.0   0.0   5.0  에이티넘인..
# 1                 창투사  +4.55%      -0.66%      10.0   0.0   6.0  에이티넘인..
# 2                  사료  +3.82%      -0.08%      13.0   1.0   4.0       한탑
# 3          코로나19(모더나)  +2.21%      +1.35%       7.0   0.0   2.0  에이비프로..
# 4           리츠(REITs)  +2.11%      +0.36%       6.0   1.0   6.0     에이리츠
# 5             일자리(취업)  +1.80%      +0.31%       4.0   0.0   3.0     대성창투
# 6        가상화폐(비트코인 등)  +1.43%      -0.45%      13.0   3.0  14.0  에이티넘인..
# 7             자동차 대표주  +1.30%      +0.54%       5.0   1.0   1.0     현대위아
# 8            크래프톤 관련주  +1.27%      -0.04%       3.0   0.0   4.0     대성창투
# 9               음식료업종  +0.69%      +1.20%      23.0   1.0  34.0       한탑
# 10      코로나19(스푸트니크V)  +0.58%       0.00%       6.0   1.0   5.0     이아이디
# 11           마켓컬리 관련주  +0.41%      -0.21%       5.0   0.0   5.0  DSC인베..
# 12            환율하락 수혜  +0.34%      +1.61%       6.0   1.0  19.0       한탑
# 13                 해운  +0.29%      +0.22%       1.0   1.0   3.0      HMM
# 14               공작기계  +0.29%      +0.24%       6.0   3.0   8.0  넥스턴바이..
# 15         선박평형수 처리장치  +0.26%      -0.54%       2.0   0.0   5.0    STX엔진
# 16           4차산업 수혜주  +0.25%      -0.03%      15.0   5.0  28.0  우리기술투..
# 17     아프리카 돼지열병(ASF)  +0.23%      +0.03%      12.0   0.0  21.0  미래생명자..
# 18        모바일게임(스마트폰)  +0.08%      +0.09%      13.0   3.0  28.0  에이프로젠..
# 19      치아 치료(임플란트 등)  +0.08%      +0.38%       6.0   1.0   6.0       바텍
# 20        LPG(액화석유가스)  +0.01%      +1.80%       2.0   0.0   6.0  중앙에너비..
# 21               생명보험   0.00%      +0.89%       3.0   1.0   3.0     동양생명
# 22     기업인수목적회사(SPAC)  -0.08%       0.00%      31.0  19.0  39.0  상상인이안..
# 23        반도체 대표주(생산)  -0.19%      -0.54%       1.0   0.0   2.0    DB하이텍
# 24    스마트카(SMART CAR)  -0.23%      +0.05%       5.0   3.0   5.0    DB하이텍
# 25        바이오인식(생체인식)  -0.27%      -0.49%       7.0   0.0  15.0       코렌
# 26  코로나19(혈장치료/혈장치료제)  -0.28%      +0.52%       4.0   0.0   5.0      녹십자
# 27         구제역/광우병 수혜  -0.29%      +0.47%       6.0   0.0  14.0     한일사료
# 28                 통신  -0.29%      +1.36%       1.0   0.0   2.0       KT
# 29                 광고  -0.32%      +0.35%       6.0   1.0  11.0     인크로스
# 30             쿠팡 관련주  -0.37%      -0.39%       8.0   2.0  13.0     디아이씨
# 31    메타버스(Metaverse)  -0.41%      -0.35%       8.0   0.0  10.0    선익시스템
# 32        콜드체인(저온 유통)  -0.44%      -0.21%       6.0   0.0   9.0    에이디칩스
# 33                전자파  -0.44%      -0.02%       3.0   2.0   7.0    켐트로닉스
# 34             시스템반도체  -0.46%      -0.95%      11.0   1.0  25.0    시그네틱스
# 35       메르스 코로나 바이러스  -0.47%      +0.22%       5.0   0.0  19.0  에이프로젠..
# 36              사물인터넷  -0.48%      +0.45%      10.0   5.0  24.0     위즈코프
# 37               블록체인  -0.56%      +0.22%       4.0   6.0  19.0     대성창투
# 38                면세점  -0.58%      +2.39%       4.0   0.0   5.0  제이에스티..
# 39            철강 주요종목  -0.58%      +3.78%       4.0   0.0   6.0    포스코강판
#
#
#       주도주.1
# 0   우리기술투..
# 1   우리기술투..
# 2      대한제당
# 3       엔투텍
# 4   ESR켄달..
# 5   DSC인베..
# 6   우리기술투..
# 7        만도
# 8   TS인베스..
# 9      대한제당
# 10      이트론
# 11      팜스코
# 12     대한제당
# 13     흥아해운
# 14  에이비프로..
# 15      엔케이
# 16     대성창투
# 17     한일사료
# 18    액션스퀘어
# 19     오스코텍
# 20     흥구석유
# 21     한화생명
# 22       비올
# 23     삼성전자
# 24       만도
# 25  바이오로그..
# 26    서린바이오
# 27     우성사료
# 28  LG유플러..
# 29  퓨쳐스트림..
# 30  미래생명자..
# 31     지니뮤직
# 32    서린바이오
# 33      제너셈
# 34     텔레칩스
# 35    서린바이오
# 36     이아이디
# 37       KT
# 38     토니모리
# 39    세아베스틸

# %%
for i in range(6):
    html = requests.get('https://finance.naver.com/sise/theme.nhn?&page={}'.format(i + 1))
    table = pd.read_html(html.text)
    if i == 0:
        stock = table[0].dropna().reset_index(drop = True)
    else:
        stock1 = table[0].dropna().reset_index(drop = True)
        stock = pd.concat([stock, stock1])

stock = stock.reset_index(drop = True)
stock
# Out:
#                  테마명    전일대비 최근3일등락률(평균) 전일대비 등락현황                 주도주  \
#                  테마명    전일대비 최근3일등락률(평균)        상승   보합    하락      주도주
# 0            두나무 관련주  +5.28%      -0.38%       6.0  0.0   5.0  에이티넘인..
# 1                창투사  +4.55%      -0.66%      10.0  0.0   6.0  에이티넘인..
# 2                 사료  +3.82%      -0.08%      13.0  1.0   4.0       한탑
# 3         코로나19(모더나)  +2.21%      +1.35%       7.0  0.0   2.0  에이비프로..
# 4          리츠(REITs)  +2.11%      +0.36%       6.0  1.0   6.0     에이리츠
# ..               ...     ...         ...       ...  ...   ...      ...
# 233           철강 중소형  -3.26%      +2.42%       3.0  1.0  23.0     동양철관
# 234               전선  -3.27%      +1.65%       0.0  0.0   6.0     대한전선
# 235  GTX(수도권 광역급행철도)  -3.57%      +2.07%       0.0  0.0  22.0    대아티아이
# 236           건설 대표주  -4.17%      +1.15%       1.0  0.0   6.0     삼성물산
# 237              페인트  -5.15%      +3.26%       0.0  0.0   8.0  강남제비스..
#
#
#        주도주.1
# 0    우리기술투..
# 1    우리기술투..
# 2       대한제당
# 3        엔투텍
# 4    ESR켄달..
# ..       ...
# 233     대동스틸
# 234     일진전기
# 235     세명전기
# 236     대우건설
# 237    삼화페인트
#
# [238 rows x 8 columns]

# %%
stock.to_excel('주식테마별시세.xlsx')
